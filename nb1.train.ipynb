# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\VINOTH\\Downloads\\GUIDE_Train.csv\\GUIDE_Train.csv")
print(df)
# Out:
#                     Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0         180388628218      0         612   123247  2024-06-04T06:05:15.000Z
# 1         455266534868     88         326   210035  2024-06-14T03:01:25.000Z
# 2        1056561957389    809       58352   712507  2024-06-13T04:52:55.000Z
# 3        1279900258736     92       32992   774301  2024-06-10T16:39:36.000Z
# 4         214748368522    148        4359   188041  2024-06-15T01:08:07.000Z
# ...                ...    ...         ...      ...                       ...
# 9516832  1056561956622      0          90   496631  2024-06-08T15:26:08.000Z
# 9516833  1228360650033     59      196410   748366  2024-06-06T09:40:08.000Z
# 9516834   867583395122     44       14117     7425  2024-06-11T22:51:03.000Z
# 9516835   395136991850     43         644     8973  2024-05-20T23:01:01.000Z
# 9516836   678604833923     16      141721   644106  2024-06-03T23:51:52.000Z
#
#          DetectorId  AlertTitle           Category MitreTechniques  \
# 0                 7           6      InitialAccess             NaN
# 1                58          43       Exfiltration             NaN
# 2               423         298      InitialAccess           T1189
# 3                 2           2  CommandAndControl             NaN
# 4                 9          74          Execution             NaN
# ...             ...         ...                ...             ...
# 9516832           7           6      InitialAccess             NaN
# 9516833           2           2  CommandAndControl             NaN
# 9516834          78          57       Exfiltration             NaN
# 9516835          52          10             Impact             NaN
# 9516836          24         348       Exfiltration             NaN
#
#           IncidentGrade  ... ResourceType Roles OSFamily OSVersion  \
# 0          TruePositive  ...          NaN   NaN        5        66
# 1         FalsePositive  ...          NaN   NaN        5        66
# 2         FalsePositive  ...          NaN   NaN        5        66
# 3        BenignPositive  ...          NaN   NaN        5        66
# 4          TruePositive  ...          NaN   NaN        5        66
# ...                 ...  ...          ...   ...      ...       ...
# 9516832    TruePositive  ...          NaN   NaN        5        66
# 9516833  BenignPositive  ...          NaN   NaN        5        66
# 9516834  BenignPositive  ...          NaN   NaN        5        66
# 9516835  BenignPositive  ...          NaN   NaN        5        66
# 9516836  BenignPositive  ...          NaN   NaN        5        66
#
#          AntispamDirection  SuspicionLevel  LastVerdict  CountryCode  State  \
# 0                      NaN             NaN          NaN           31      6
# 1                      NaN             NaN          NaN          242   1445
# 2                      NaN      Suspicious   Suspicious          242   1445
# 3                      NaN      Suspicious   Suspicious          242   1445
# 4                      NaN             NaN          NaN          242   1445
# ...                    ...             ...          ...          ...    ...
# 9516832                NaN             NaN          NaN          242   1445
# 9516833                NaN      Suspicious   Suspicious          242   1445
# 9516834                NaN             NaN          NaN          242   1445
# 9516835                NaN             NaN          NaN          242   1445
# 9516836                NaN             NaN          NaN          242   1445
#
#           City
# 0            3
# 1        10630
# 2        10630
# 3        10630
# 4        10630
# ...        ...
# 9516832  10630
# 9516833  10630
# 9516834  10630
# 9516835  10630
# 9516836  10630
#
# [9516837 rows x 45 columns]

# %%
import pandas as pd
df = pd.read_csv("C:/Users/VINOTH/Downloads/GUIDE_Train.csv/GUIDE_Train.csv")
print(df)
# Out:
#                     Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0         180388628218      0         612   123247  2024-06-04T06:05:15.000Z
# 1         455266534868     88         326   210035  2024-06-14T03:01:25.000Z
# 2        1056561957389    809       58352   712507  2024-06-13T04:52:55.000Z
# 3        1279900258736     92       32992   774301  2024-06-10T16:39:36.000Z
# 4         214748368522    148        4359   188041  2024-06-15T01:08:07.000Z
# ...                ...    ...         ...      ...                       ...
# 9516832  1056561956622      0          90   496631  2024-06-08T15:26:08.000Z
# 9516833  1228360650033     59      196410   748366  2024-06-06T09:40:08.000Z
# 9516834   867583395122     44       14117     7425  2024-06-11T22:51:03.000Z
# 9516835   395136991850     43         644     8973  2024-05-20T23:01:01.000Z
# 9516836   678604833923     16      141721   644106  2024-06-03T23:51:52.000Z
#
#          DetectorId  AlertTitle           Category MitreTechniques  \
# 0                 7           6      InitialAccess             NaN
# 1                58          43       Exfiltration             NaN
# 2               423         298      InitialAccess           T1189
# 3                 2           2  CommandAndControl             NaN
# 4                 9          74          Execution             NaN
# ...             ...         ...                ...             ...
# 9516832           7           6      InitialAccess             NaN
# 9516833           2           2  CommandAndControl             NaN
# 9516834          78          57       Exfiltration             NaN
# 9516835          52          10             Impact             NaN
# 9516836          24         348       Exfiltration             NaN
#
#           IncidentGrade  ... ResourceType Roles OSFamily OSVersion  \
# 0          TruePositive  ...          NaN   NaN        5        66
# 1         FalsePositive  ...          NaN   NaN        5        66
# 2         FalsePositive  ...          NaN   NaN        5        66
# 3        BenignPositive  ...          NaN   NaN        5        66
# 4          TruePositive  ...          NaN   NaN        5        66
# ...                 ...  ...          ...   ...      ...       ...
# 9516832    TruePositive  ...          NaN   NaN        5        66
# 9516833  BenignPositive  ...          NaN   NaN        5        66
# 9516834  BenignPositive  ...          NaN   NaN        5        66
# 9516835  BenignPositive  ...          NaN   NaN        5        66
# 9516836  BenignPositive  ...          NaN   NaN        5        66
#
#          AntispamDirection  SuspicionLevel  LastVerdict  CountryCode  State  \
# 0                      NaN             NaN          NaN           31      6
# 1                      NaN             NaN          NaN          242   1445
# 2                      NaN      Suspicious   Suspicious          242   1445
# 3                      NaN      Suspicious   Suspicious          242   1445
# 4                      NaN             NaN          NaN          242   1445
# ...                    ...             ...          ...          ...    ...
# 9516832                NaN             NaN          NaN          242   1445
# 9516833                NaN      Suspicious   Suspicious          242   1445
# 9516834                NaN             NaN          NaN          242   1445
# 9516835                NaN             NaN          NaN          242   1445
# 9516836                NaN             NaN          NaN          242   1445
#
#           City
# 0            3
# 1        10630
# 2        10630
# 3        10630
# 4        10630
# ...        ...
# 9516832  10630
# 9516833  10630
# 9516834  10630
# 9516835  10630
# 9516836  10630
#
# [9516837 rows x 45 columns]

# %%
df.columns
# Out:
# Index(['Id', 'OrgId', 'IncidentId', 'AlertId', 'Timestamp', 'DetectorId',
#        'AlertTitle', 'Category', 'MitreTechniques', 'IncidentGrade',
#        'ActionGrouped', 'ActionGranular', 'EntityType', 'EvidenceRole',
#        'DeviceId', 'Sha256', 'IpAddress', 'Url', 'AccountSid', 'AccountUpn',
#        'AccountObjectId', 'AccountName', 'DeviceName', 'NetworkMessageId',
#        'EmailClusterId', 'RegistryKey', 'RegistryValueName',
#        'RegistryValueData', 'ApplicationId', 'ApplicationName',
#        'OAuthApplicationId', 'ThreatFamily', 'FileName', 'FolderPath',
#        'ResourceIdName', 'ResourceType', 'Roles', 'OSFamily', 'OSVersion',
#        'AntispamDirection', 'SuspicionLevel', 'LastVerdict', 'CountryCode',
#        'State', 'City'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Id                          0
# OrgId                       0
# IncidentId                  0
# AlertId                     0
# Timestamp                   0
# DetectorId                  0
# AlertTitle                  0
# Category                    0
# MitreTechniques       5468386
# IncidentGrade           51340
# ActionGrouped         9460773
# ActionGranular        9460773
# EntityType                  0
# EvidenceRole                0
# DeviceId                    0
# Sha256                      0
# IpAddress                   0
# Url                         0
# AccountSid                  0
# AccountUpn                  0
# AccountObjectId             0
# AccountName                 0
# DeviceName                  0
# NetworkMessageId            0
# EmailClusterId        9420025
# RegistryKey                 0
# RegistryValueName           0
# RegistryValueData           0
# ApplicationId               0
# ApplicationName             0
# OAuthApplicationId          0
# ThreatFamily          9441956
# FileName                    0
# FolderPath                  0
# ResourceIdName              0
# ResourceType          9509762
# Roles                 9298686
# OSFamily                    0
# OSVersion                   0
# AntispamDirection     9339535
# SuspicionLevel        8072708
# LastVerdict           7282572
# CountryCode                 0
# State                       0
# City                        0
# dtype: int64

# %%
df.head(5)
# Out:
#               Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0   180388628218      0         612   123247  2024-06-04T06:05:15.000Z
# 1   455266534868     88         326   210035  2024-06-14T03:01:25.000Z
# 2  1056561957389    809       58352   712507  2024-06-13T04:52:55.000Z
# 3  1279900258736     92       32992   774301  2024-06-10T16:39:36.000Z
# 4   214748368522    148        4359   188041  2024-06-15T01:08:07.000Z
#
#    DetectorId  AlertTitle           Category MitreTechniques   IncidentGrade  \
# 0           7           6      InitialAccess             NaN    TruePositive
# 1          58          43       Exfiltration             NaN   FalsePositive
# 2         423         298      InitialAccess           T1189   FalsePositive
# 3           2           2  CommandAndControl             NaN  BenignPositive
# 4           9          74          Execution             NaN    TruePositive
#
#    ... ResourceType Roles OSFamily OSVersion  AntispamDirection  \
# 0  ...          NaN   NaN        5        66                NaN
# 1  ...          NaN   NaN        5        66                NaN
# 2  ...          NaN   NaN        5        66                NaN
# 3  ...          NaN   NaN        5        66                NaN
# 4  ...          NaN   NaN        5        66                NaN
#
#    SuspicionLevel  LastVerdict  CountryCode  State   City
# 0             NaN          NaN           31      6      3
# 1             NaN          NaN          242   1445  10630
# 2      Suspicious   Suspicious          242   1445  10630
# 3      Suspicious   Suspicious          242   1445  10630
# 4             NaN          NaN          242   1445  10630
#
# [5 rows x 45 columns]

# %%
import pandas as pd

pd.set_option('display.max_columns', None)  # Show all columns

# %%
df.head(5)
# Out:
#               Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0   180388628218      0         612   123247  2024-06-04T06:05:15.000Z
# 1   455266534868     88         326   210035  2024-06-14T03:01:25.000Z
# 2  1056561957389    809       58352   712507  2024-06-13T04:52:55.000Z
# 3  1279900258736     92       32992   774301  2024-06-10T16:39:36.000Z
# 4   214748368522    148        4359   188041  2024-06-15T01:08:07.000Z
#
#    DetectorId  AlertTitle           Category MitreTechniques   IncidentGrade  \
# 0           7           6      InitialAccess             NaN    TruePositive
# 1          58          43       Exfiltration             NaN   FalsePositive
# 2         423         298      InitialAccess           T1189   FalsePositive
# 3           2           2  CommandAndControl             NaN  BenignPositive
# 4           9          74          Execution             NaN    TruePositive
#
#   ActionGrouped ActionGranular EntityType EvidenceRole  DeviceId  Sha256  \
# 0           NaN            NaN         Ip      Related     98799  138268
# 1           NaN            NaN       User     Impacted     98799  138268
# 2           NaN            NaN        Url      Related     98799  138268
# 3           NaN            NaN        Url      Related     98799  138268
# 4           NaN            NaN       User     Impacted     98799  138268
#
#    IpAddress     Url  AccountSid  AccountUpn  AccountObjectId  AccountName  \
# 0         27  160396      441377      673934           425863       453297
# 1     360606  160396       22406       23032            22795        24887
# 2     360606   68652      441377      673934           425863       453297
# 3     360606      13      441377      673934           425863       453297
# 4     360606  160396         449         592              440          479
#
#    DeviceName  NetworkMessageId  EmailClusterId  RegistryKey  \
# 0      153085            529644             NaN         1631
# 1      153085            529644             NaN         1631
# 2      153085            529644             NaN         1631
# 3      153085            529644             NaN         1631
# 4      153085            529644             NaN         1631
#
#    RegistryValueName  RegistryValueData  ApplicationId  ApplicationName  \
# 0                635                860           2251             3421
# 1                635                860           2251             3421
# 2                635                860           2251             3421
# 3                635                860           2251             3421
# 4                635                860           2251             3421
#
#    OAuthApplicationId ThreatFamily  FileName  FolderPath  ResourceIdName  \
# 0                 881          NaN    289573      117668            3586
# 1                 881          NaN    289573      117668            3586
# 2                 881          NaN    289573      117668            3586
# 3                 881          NaN    289573      117668            3586
# 4                 881          NaN    289573      117668            3586
#
#   ResourceType Roles  OSFamily  OSVersion AntispamDirection SuspicionLevel  \
# 0          NaN   NaN         5         66               NaN            NaN
# 1          NaN   NaN         5         66               NaN            NaN
# 2          NaN   NaN         5         66               NaN     Suspicious
# 3          NaN   NaN         5         66               NaN     Suspicious
# 4          NaN   NaN         5         66               NaN            NaN
#
#   LastVerdict  CountryCode  State   City
# 0         NaN           31      6      3
# 1         NaN          242   1445  10630
# 2  Suspicious          242   1445  10630
# 3  Suspicious          242   1445  10630
# 4         NaN          242   1445  10630

# %%
df.isnull().sum()
df.dropna(thresh=0.9 * len(df), axis=1, inplace=True)  # drop columns with >90% NaNs

# %%
df.isnull().sum()
# Out:
# Id                        0
# OrgId                     0
# IncidentId                0
# AlertId                   0
# Timestamp                 0
# DetectorId                0
# AlertTitle                0
# Category                  0
# IncidentGrade         51340
# EntityType                0
# EvidenceRole              0
# DeviceId                  0
# Sha256                    0
# IpAddress                 0
# Url                       0
# AccountSid                0
# AccountUpn                0
# AccountObjectId           0
# AccountName               0
# DeviceName                0
# NetworkMessageId          0
# RegistryKey               0
# RegistryValueName         0
# RegistryValueData         0
# ApplicationId             0
# ApplicationName           0
# OAuthApplicationId        0
# FileName                  0
# FolderPath                0
# ResourceIdName            0
# OSFamily                  0
# OSVersion                 0
# CountryCode               0
# State                     0
# City                      0
# dtype: int64

# %%
df = df[df['IncidentGrade'].notnull()]

# %%
df.isnull().sum()
# Out:
# Id                    0
# OrgId                 0
# IncidentId            0
# AlertId               0
# Timestamp             0
# DetectorId            0
# AlertTitle            0
# Category              0
# IncidentGrade         0
# EntityType            0
# EvidenceRole          0
# DeviceId              0
# Sha256                0
# IpAddress             0
# Url                   0
# AccountSid            0
# AccountUpn            0
# AccountObjectId       0
# AccountName           0
# DeviceName            0
# NetworkMessageId      0
# RegistryKey           0
# RegistryValueName     0
# RegistryValueData     0
# ApplicationId         0
# ApplicationName       0
# OAuthApplicationId    0
# FileName              0
# FolderPath            0
# ResourceIdName        0
# OSFamily              0
# OSVersion             0
# CountryCode           0
# State                 0
# City                  0
# dtype: int64

# %%
df.dtypes
# Out:
# Id                     int64
# OrgId                  int64
# IncidentId             int64
# AlertId                int64
# Timestamp             object
# DetectorId             int64
# AlertTitle             int64
# Category              object
# IncidentGrade         object
# EntityType            object
# EvidenceRole          object
# DeviceId               int64
# Sha256                 int64
# IpAddress              int64
# Url                    int64
# AccountSid             int64
# AccountUpn             int64
# AccountObjectId        int64
# AccountName            int64
# DeviceName             int64
# NetworkMessageId       int64
# RegistryKey            int64
# RegistryValueName      int64
# RegistryValueData      int64
# ApplicationId          int64
# ApplicationName        int64
# OAuthApplicationId     int64
# FileName               int64
# FolderPath             int64
# ResourceIdName         int64
# OSFamily               int64
# OSVersion              int64
# CountryCode            int64
# State                  int64
# City                   int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# Step 1: Identify categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Step 2: Initialize label encoder
le = LabelEncoder()

# Step 3: Apply label encoding to each categorical column
for col in categorical_cols:
    df[col] = df[col].astype(str)  # Convert to string if needed
    df[col] = le.fit_transform(df[col])

# %%
import pickle

with open("label_encoder.pkl", "wb") as f:
    pickle.dump(le, f)

# %% [markdown]
# Train/Validation Split

# %%
from sklearn.model_selection import train_test_split

X = df.drop('IncidentGrade', axis=1)  # features
y = df['IncidentGrade']               # target (already encoded as integers)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
from xgboost import XGBClassifier
from sklearn.feature_selection import SelectFromModel

# Train initial model
model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)
model.fit(X_train, y_train)

# Feature selection
selector = SelectFromModel(estimator=model, threshold='median', prefit=True)

# Get boolean mask of selected features
mask = selector.get_support()

# List of all feature names
all_features = X_train.columns

# Get selected and removed features
selected_features = all_features[mask]
removed_features = all_features[~mask]

print("✅ Selected Features:")
print(selected_features.tolist())

print("\n❌ Removed Features:")
print(removed_features.tolist())
# Out:
# C:\Users\VINOTH\AppData\Roaming\Python\Python312\site-packages\xgboost\training.py:183: UserWarning: [15:25:24] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Selected Features:
# ['OrgId', 'IncidentId', 'AlertId', 'DetectorId', 'AlertTitle', 'Category', 'EntityType', 'EvidenceRole', 'DeviceId', 'Sha256', 'AccountUpn', 'AccountObjectId', 'DeviceName', 'NetworkMessageId', 'RegistryKey', 'OSFamily', 'CountryCode']
#
# ❌ Removed Features:
# ['Id', 'Timestamp', 'IpAddress', 'Url', 'AccountSid', 'AccountName', 'RegistryValueName', 'RegistryValueData', 'ApplicationId', 'ApplicationName', 'OAuthApplicationId', 'FileName', 'FolderPath', 'ResourceIdName', 'OSVersion', 'State', 'City']

# %% [markdown]
# #MODEL RUNNING

# %%
from xgboost import XGBClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import classification_report, confusion_matrix, f1_score, precision_score, recall_score

# Step 1: Train initial model
initial_model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)
initial_model.fit(X_train, y_train)

# Step 2: Select important features
selector = SelectFromModel(estimator=initial_model, threshold='median', prefit=True)

# Step 3: Get selected feature names (optional, for display)
selected_feature_mask = selector.get_support()
selected_feature_names = X_train.columns[selected_feature_mask]
print("✅ Selected Features:")
print(selected_feature_names.tolist())

# Step 4: Transform datasets
X_train_selected = selector.transform(X_train)
X_test_selected = selector.transform(X_test)

# Step 5: Train model on selected features
model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)
model.fit(X_train_selected, y_train)

# Step 6: Predict
y_pred = model.predict(X_test_selected)

# Step 7: Evaluation
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))

macro_f1 = f1_score(y_test, y_pred, average='macro')
macro_precision = precision_score(y_test, y_pred, average='macro')
macro_recall = recall_score(y_test, y_pred, average='macro')

print(f"\nMacro F1 Score: {macro_f1:.4f}")
print(f"Macro Precision: {macro_precision:.4f}")
print(f"Macro Recall: {macro_recall:.4f}")

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# C:\Users\VINOTH\AppData\Roaming\Python\Python312\site-packages\xgboost\training.py:183: UserWarning: [15:32:02] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Selected Features:
# ['OrgId', 'IncidentId', 'AlertId', 'DetectorId', 'AlertTitle', 'Category', 'EntityType', 'EvidenceRole', 'DeviceId', 'Sha256', 'AccountUpn', 'AccountObjectId', 'DeviceName', 'NetworkMessageId', 'RegistryKey', 'OSFamily', 'CountryCode']
# C:\Users\VINOTH\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# C:\Users\VINOTH\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# C:\Users\VINOTH\AppData\Roaming\Python\Python312\site-packages\xgboost\training.py:183: UserWarning: [15:34:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8861    0.9540    0.9188    822164
#            1     0.9234    0.8378    0.8785    406393
#            2     0.9432    0.9072    0.9248    664543
#
#     accuracy                         0.9126   1893100
#    macro avg     0.9176    0.8997    0.9074   1893100
# weighted avg     0.9141    0.9126    0.9123   1893100
#
#
# Macro F1 Score: 0.9074
# Macro Precision: 0.9176
# Macro Recall: 0.8997
#
# Confusion Matrix:
# [[784352  17988  19824]
#  [ 49410 340474  16509]
#  [ 51405  10248 602890]]

# %%
import pickle

# Save model to a file
with open("xgb_model.pkl", "wb") as file:
    pickle.dump(model, file)

print("Model saved as xgb_model.pkl")
# Out:
# Model saved as xgb_model.pkl
